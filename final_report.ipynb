# %% [markdown]
# # Board Report

# %% [markdown]
# **Background**
#
# I have some questions for you that I need to be answered before the board meeting Thursday afternoon. I need to be able to speak to the following questions. My questions are listed below; however, if you discover anything else important that I didn’t think to ask, please include that as well.

# %%
import matplotlib.pyplot as plt

import sys
sys.path.append("./victoire")
import explore_victoire_

# %% [markdown]
# ### 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
# Load solution from victoire folder
explore_victoire_.get_explore_question_1().set_index("cohort_id")
# Out:
#            program_id          lesson  referred_to_lesson_count
# cohort_id
# 1.0               1.0    javascript-i                      1039
# 2.0               1.0         content                        57
# 4.0               1.0         prework                         2
# 6.0               1.0   javascript-ii                        11
# 7.0               1.0         content                       245
# 8.0               1.0        java-iii                       155
# 11.0              1.0         content                        79
# 12.0              1.0         content                       258
# 13.0              1.0         content                      2254
# 14.0              1.0         content                      1128
# 17.0              1.0         content                      1359
# 19.0              1.0         content                       650
# 15.0              2.0         content                       241
# ...

# %% [markdown]
# ### 2. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?

# %%
plt.ioff()
# Load solution from victoire folder
explore_victoire_.get_explore_question_2()

# %% [markdown]
# - Cohort 33 and 135 have refered to the javascript-1 lessons significantly more than others.

# %% [markdown]
# ### 3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?

# %% [markdown]
# ### 4. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?

# %% [markdown]
# ### 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?

# %% [markdown]
# ### 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?
